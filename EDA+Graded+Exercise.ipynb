# %%
#import the warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
att= pd.read_csv("Attribute+DataSet.csv")
sale= pd.read_csv("Dress+Sales.csv")

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %%
att.Price.describe()
# Out:
# count         477
# unique          5
# top       Average
# freq          240
# Name: Price, dtype: object

# %%
att.Price.values
# Out:
# array(['Low', 'Low', 'High', 'Average', 'Low', 'Low', 'Average',
#        'Average', 'Low', 'Average', 'Average', 'Low', 'Average', 'Low',
#        'Low', 'Average', 'Medium', 'Average', 'Average', 'Average', 'Low',
#        'Low', 'Average', 'Average', 'Average', 'Average', 'Low', 'Low',
#        'Low', 'Average', 'Low', 'Average', 'Average', 'High', 'Low',
#        'Average', 'Average', 'Average', 'Average', 'Average', 'Low',
#        'Average', 'Low', 'Average', 'Average', 'Average', 'Average',
#        'Low', 'Medium', 'Low', 'Low', 'Average', 'Average', 'Average',
#        'Average', 'Average', 'Low', 'Low', 'Average', 'High', 'Average',
#        'Average', 'Average', 'Low', 'Average', 'Low', 'Medium', 'Average',
#        'Medium', 'Average', 'Low', 'Average', 'Low', 'Low', 'Low',
#        'Average', 'Low', 'Average', 'very-high', 'Low', 'Average', 'Low',
#        'Low', 'Average', 'Low', 'Low', 'Average', 'Low', 'Average',
# ...

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %%
att.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
att.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
att.loc[att.Size=="s","Size"] = "S"

# %%
att.loc[att.Size=="small","Size"] = "S"

# %%
att[att.Size!="S"].shape
# Out:
# (443, 13)

# %%
att.Size.value_counts(normalize=True)
# Out:
# M       0.356994
# free    0.344468
# L       0.194154
# S       0.075157
# XL      0.029228
# Name: Size, dtype: float64

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.

# %%
# Print the value counts of each category in "Size" column.

# %% [markdown]
# ### Impute/Remove Missing values

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
sale["09-12-2013"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <module>
# ----> 1 sale["09-12-2013"].astype("float")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5815, in NDFrame.astype(self, dtype, copy, errors)
#    5808     results = [
#    5809         self.iloc[:, i].astype(dtype, copy=copy)
#    5810         for i in range(len(self.columns))
#    5811     ]
#    5813 else:
#    5814     # else, only a single dtype is given
# -> 5815     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816     return self._constructor(new_data).__finalize__(self, method="astype")
#    5818 # GH 33113: handle empty frame or series
#
# ...

# %%
# Print the null count of each variables of inp0 and inp1.
sale.loc[sale['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

sale.loc[sale['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

sale.loc[sale['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

sale.loc[sale['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

sale.loc[sale['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

sale.loc[sale['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
sale.dtypes
# Out:
# Dress_ID      float64
# 29-08-2013      int64
# 31-08-2013      int64
# 09-02-2013      int64
# 09-04-2013      int64
# 09-06-2013      int64
# 09-08-2013      int64
# 09-10-2013      int64
# 09-12-2013     object
# 14-09-2013     object
# 16-09-2013     object
# 18-09-2013     object
# 20-09-2013     object
# 22-09-2013     object
# 24-09-2013      int64
# 28-09-2013      int64
# 10-06-2013      int64
# 10-12-2013      int64
# Spring          int64
# Summer          int64
# dtype: object

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
sale=sale.astype("float64")

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
sale.isnull().sum()
# Out:
# Dress_ID      0
# 29-08-2013    0
# 31-08-2013    0
# 09-02-2013    0
# 09-04-2013    0
# 09-06-2013    0
# 09-08-2013    0
# 09-10-2013    0
# 09-12-2013    1
# 14-09-2013    1
# 16-09-2013    1
# 18-09-2013    1
# 20-09-2013    1
# 22-09-2013    1
# 24-09-2013    0
# 28-09-2013    0
# 10-06-2013    0
# 10-12-2013    0
# Spring        0
# Summer        0
# dtype: int64

# %% [markdown]
# # Drop the columns in "Dress Sales" which have more than 40% of missing values.
# sale= sale.drop(["26-09-2013"] , axis= 1)
#
# sale= sale.drop(["30-09-2013"] , axis= 1)
#
# sale= sale.drop(["10-02-2013"] , axis= 1)
#
# sale= sale.drop(["10-04-2013"] , axis= 1)
#
# sale= sale.drop(["10-08-2013"] , axis= 1)
#
# sale= sale.drop(["10-10-2013"] , axis= 1)

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
sale.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09      2114.0      2274.0      2491.0      2660.0      2727.0
# 1  1.212192e+09       151.0       275.0       570.0       750.0       813.0
# 2  1.190381e+09         6.0         7.0         7.0         7.0         8.0
# 3  9.660060e+08      1005.0      1128.0      1326.0      1455.0      1507.0
# 4  8.763395e+08       996.0      1175.0      1304.0      1396.0      1432.0
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  16-09-2013  18-09-2013  \
# 0      2887.0      2930.0      3119.0      3204.0      3277.0      3321.0
# 1      1066.0      1164.0      1558.0      1756.0      1878.0      1985.0
# 2         8.0         9.0        10.0        10.0        10.0        10.0
# 3      1621.0      1637.0      1723.0      1746.0      1783.0      1796.0
# 4      1559.0      1570.0      1638.0      1655.0      1681.0      1743.0
#
# ...

# %%
sale.dtypes
# Out:
# Dress_ID      float64
# 29-08-2013    float64
# 31-08-2013    float64
# 09-02-2013    float64
# 09-04-2013    float64
# 09-06-2013    float64
# 09-08-2013    float64
# 09-10-2013    float64
# 09-12-2013    float64
# 14-09-2013    float64
# 16-09-2013    float64
# 18-09-2013    float64
# 20-09-2013    float64
# 22-09-2013    float64
# 24-09-2013    float64
# 28-09-2013    float64
# 10-06-2013    float64
# 10-12-2013    float64
# Spring        float64
# Summer        float64
# dtype: object

# %%
# Create the four seasons columns in inp1, according to the above criteria.
sale['Spring'] = sale.apply(lambda x: x['09-04-2013'], axis=1)

sale['Summer'] = sale.apply(lambda x: x['29-08-2013'] + x['31-08-2013']+ x['09-06-2013']+ x['09-08-2013']+ x['10-06-2013'], axis=1)

sale['Winter'] = sale.apply(lambda x: x['09-02-2013'] + x['09-12-2013']+ x['10-12-2013'], axis=1)

sale['Autumn'] = sale.apply(lambda x: x['09-10-2013'] + x['14-09-2013']+ x['16-09-2013']+ x['18-09-2013']+ x['20-09-2013']+ x['22-09-2013']+ x['24-09-2013']+ x['28-09-2013'], axis=1)
sale["total"] = sale.apply(lambda x: x['Spring'] + x['Summer']+ x['Winter']+ x['Autumn'], axis=1)

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
sale.sum()
# Out:
# Dress_ID      4.301795e+11
# 29-08-2013    9.413200e+04
# 31-08-2013    9.958800e+04
# 09-02-2013    1.065600e+05
# 09-04-2013    1.425960e+05
# 09-06-2013    1.449630e+05
# 09-08-2013    1.505770e+05
# 09-10-2013    1.522650e+05
# 09-12-2013    1.586640e+05
# 14-09-2013    1.617530e+05
# 16-09-2013    1.642510e+05
# 18-09-2013    1.667630e+05
# 20-09-2013    1.712760e+05
# 22-09-2013    1.757410e+05
# 24-09-2013    1.767880e+05
# 28-09-2013    1.847060e+05
# 10-06-2013    1.968010e+05
# 10-12-2013    2.056360e+05
# Spring        1.425960e+05
# Summer        6.860610e+05
# Winter        4.708600e+05
# Autumn        1.353543e+06
# total         2.653060e+06
# dtype: float64

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
mrg = pd.merge(left=att,right=sale, how='left', left_on='Dress_ID', right_on='Dress_ID')
mrg.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  ... 22-09-2013 24-09-2013  28-09-2013  \
# 0            NaN    chiffon  ...     3479.0     3554.0      3706.0
# 1     microfiber        NaN  ...     2454.0     2710.0      3258.0
# 2       polyster        NaN  ...       11.0       11.0        11.0
# 3           silk    chiffon  ...     1845.0     1878.0      1914.0
# 4  chiffonfabric    chiffon  ...     1919.0     2032.0      2252.0
#
#    10-06-2013  10-12-2013  Spring   Summer  Winter   Autumn    total
# ...

# %% [markdown]
# #### Now Drop the Date columns from inp0 as it is already combined into four seasons.

# %%
mrg.drop(mrg.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
mrg.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               0
# Rating              0
# Size                0
# Season              0
# NeckLine            0
# SleeveLength        0
# Material          116
# FabricType        250
# Decoration        220
# Pattern Type       98
# Recommendation      0
# Spring              1
# Summer              1
# Winter              1
# Autumn              1
# total               1
# dtype: int64

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
att = att[~att.Price.isnull()]

att = att[~att.Season.isnull()]

att = att[~att.NeckLine.isnull()]

att = att[~att.SleeveLength.isnull()]

sale = sale[~sale.Winter.isnull()]

sale = sale[~sale.Autumn.isnull()]

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
mrg.Season= mrg.Season.replace('Automn', "Autumn")

mrg.Season= mrg.Season.replace('spring', "Spring")

mrg.Season= mrg.Season.replace('winter', "Winter")

# %%
#correcting the Spellings.
mrg.SleeveLength= mrg.SleeveLength.replace(['cap-sleeves', 'capsleeves'], "cap sleeves")

mrg.SleeveLength= mrg.SleeveLength.replace('full', "full sleeves")

mrg.SleeveLength= mrg.SleeveLength.replace(['half','halfsleeve'], "half sleeves")

mrg.SleeveLength= mrg.SleeveLength.replace(['sleevless', 'sleeevless', 'sleeveless', 'sleveless'], "sleeve less")

mrg.SleeveLength= mrg.SleeveLength.replace(['threequarter','threequater', 'thressqatar'], "three quater")

mrg.SleeveLength= mrg.SleeveLength.replace(['turndowncollor','urndowncollor'], "turn down collar")

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion  -----Ans
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare ----Ans

# %%
mrg.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine  SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck   sleeve less
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck         Petal
# 2  1190380701  vintage     High     0.0    L  Autumn   o-neck  full sleeves
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck  full sleeves
# 4   876339541     cute      Low     4.5    M  Summer   o-neck     butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Spring  \
# 0            NaN    chiffon     ruffles       animal               1  2660.0
# 1     microfiber        NaN     ruffles       animal               0   750.0
# 2       polyster        NaN         NaN        print               0     7.0
# 3           silk    chiffon  embroidary        print               1  1455.0
# 4  chiffonfabric    chiffon         bow          dot               0  1396.0
#
#     Summer  Winter   Autumn    total
# ...

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
mrg.groupby(by=["Style"]).sum()<50000
# Out:
#           Dress_ID  Rating  Recommendation  Spring  Summer  Winter  Autumn  \
# Style
# Brief        False    True            True    True    True    True   False
# Casual       False    True            True   False   False   False   False
# Flare        False    True            True    True    True    True    True
# Novelty      False    True            True    True    True    True    True
# OL           False    True            True    True    True    True    True
# Sexy         False    True            True    True   False   False   False
# bohemian     False    True            True    True    True    True    True
# cute         False    True            True    True   False   False   False
# fashion      False    True            True    True    True    True    True
# party        False    True            True    True    True    True   False
# sexy         False    True            True    True    True    True    True
# ...

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%----Answer
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
mrg.Style.value_counts(normalize=True)
# Out:
# Casual      0.459746
# Sexy        0.137712
# party       0.101695
# cute        0.091102
# vintage     0.052966
# bohemian    0.048729
# Brief       0.036017
# work        0.036017
# sexy        0.014831
# Novelty     0.012712
# Flare       0.004237
# OL          0.002119
# fashion     0.002119
# Name: Style, dtype: float64

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
mrg.groupby(by="NeckLine").sum()<50000
# Out:
#                  Dress_ID  Rating  Recommendation  Spring  Summer  Winter  \
# NeckLine
# Scoop               False    True            True    True    True    True
# Sweetheart          False    True            True    True    True    True
# backless            False    True            True    True    True    True
# boat-neck           False    True            True    True    True    True
# bowneck             False    True            True    True    True    True
# halter              False    True            True    True    True    True
# mandarin-collor     False    True            True    True    True    True
# o-neck              False    True            True   False   False   False
# open                False    True            True    True    True    True
# peterpan-collor     False    True            True    True    True    True
# ruffled             False    True            True    True    True    True
# ...

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
mrg.groupby(by="SleeveLength").sum()<50000
# Out:
#                   Dress_ID  Rating  Recommendation  Spring  Summer  Winter  \
# SleeveLength
# Petal                False    True            True    True    True    True
# butterfly            False    True            True    True    True    True
# cap sleeves          False    True            True    True    True    True
# full sleeves         False    True            True    True   False   False
# half sleeves         False    True            True    True   False    True
# short                False    True            True    True   False   False
# sleeve less          False    True            True   False   False   False
# three quater         False    True            True    True   False    True
# turn down collar     False    True            True    True    True    True
#
#                   Autumn  total
# SleeveLength
# Petal               True   True
# butterfly           True   True
# cap sleeves         True   True
# full sleeves       False  False
# ...

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
mrg.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine  SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck   sleeve less
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck         Petal
# 2  1190380701  vintage     High     0.0    L  Autumn   o-neck  full sleeves
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck  full sleeves
# 4   876339541     cute      Low     4.5    M  Summer   o-neck     butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Spring  \
# 0            NaN    chiffon     ruffles       animal               1  2660.0
# 1     microfiber        NaN     ruffles       animal               0   750.0
# 2       polyster        NaN         NaN        print               0     7.0
# 3           silk    chiffon  embroidary        print               1  1455.0
# 4  chiffonfabric    chiffon         bow          dot               0  1396.0
#
#     Summer  Winter   Autumn    total
# ...

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
mrg.groupby(by="Material").sum()<25000
# Out:
#                Dress_ID  Rating  Recommendation  Spring  Summer  Winter  \
# Material
# acrylic           False    True            True    True    True    True
# cashmere          False    True            True    True    True    True
# chiffonfabric     False    True            True    True   False   False
# cotton            False    True            True   False   False   False
# lace              False    True            True    True    True    True
# linen             False    True            True    True    True    True
# lycra             False    True            True    True    True    True
# microfiber        False    True            True    True    True    True
# milksilk          False    True            True    True    True    True
# mix               False    True            True    True    True    True
# modal             False    True            True    True    True    True
# model             False    True            True    True    True    True
# ...

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
mrg.groupby(by="FabricType").sum()<25000
# Out:
#             Dress_ID  Rating  Recommendation  Spring  Summer  Winter  Autumn  \
# FabricType
# Corduroy       False    True            True    True    True    True    True
# batik          False    True            True    True    True    True    True
# broadcloth     False    True            True    True   False    True   False
# chiffon        False    True            True   False   False   False   False
# dobby          False    True            True    True    True    True    True
# flannael       False    True            True    True    True    True    True
# flannel        False    True            True    True    True    True    True
# jersey         False    True            True    True   False    True   False
# knitted        False    True            True    True    True    True    True
# knitting       False    True            True    True    True    True    True
# lace           False    True            True    True    True    True    True
# ...

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
mrg.groupby(by="Pattern Type").sum()<25000
# Out:
#               Dress_ID  Rating  Recommendation  Spring  Summer  Winter  \
# Pattern Type
# animal           False    True            True    True   False   False
# character        False    True            True    True    True    True
# dot              False    True            True    True   False   False
# floral           False    True            True    True    True    True
# geometric        False    True            True    True   False    True
# leapord          False    True            True    True    True    True
# leopard          False    True            True    True    True    True
# none             False    True            True    True    True    True
# patchwork        False    True            True    True   False   False
# plaid            False    True            True    True    True    True
# print            False    True            True    True   False   False
# solid            False    True            True   False   False   False
# ...

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
mrg.groupby(by="Decoration").sum()<25000
# Out:
#             Dress_ID  Rating  Recommendation  Spring  Summer  Winter  Autumn  \
# Decoration
# Tiered         False    True            True    True    True    True    True
# applique       False    True            True    True    True    True   False
# beading        False    True            True    True    True    True   False
# bow            False    True            True    True   False   False   False
# button         False    True            True    True    True    True    True
# cascading      False    True            True    True    True    True    True
# crystal        False    True            True    True    True    True    True
# draped         False    True            True    True    True    True    True
# embroidary     False    True            True    True    True    True    True
# feathers       False    True            True    True    True    True    True
# flowers        False    True            True    True    True    True    True
# ...

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style  ---Ans
# - Price
# - Season
# - Size

# %%
att.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
mrg.Autumn.describe()
# Out:
# count      471.000000
# mean      2852.849257
# std       5037.033044
# min          1.000000
# 25%        410.500000
# 50%       1334.000000
# 75%       3126.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
mrg.Autumn.quantile(1)-mrg.Autumn.quantile(0.75)
# Out:
# 52406.0

# %%
# plot the boxplot of "Autumn" column.
sns.boxplot(mrg.Autumn)
plt.show()

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn  --- Ans

# %%
# Find the maximum and 99th percentile of Winter season.
mrg.Winter.quantile(1)-mrg.Winter.quantile(0.99)
# Out:
# 11402.69999999999

# %%
# Find the maximum and 99th percentile of Summer season.
mrg.Summer.quantile(1)-mrg.Summer.quantile(0.99)
# Out:
# 21602.999999999996

# %%
# Find the maximum and 99th percentile of Spring season.
mrg.Spring.quantile(1)-mrg.Spring.quantile(0.99)
# Out:
# 4716.8

# %%
# Find the maximum and 99th percentile of Autumn season.
mrg.Autumn.quantile(1)-mrg.Autumn.quantile(0.99)
# Out:
# 31397.999999999975

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High  --- Ans

# %%
# Find the Mean of Ratings for each Price category.
mrg.groupby(by="Price").Rating.mean()
# Out:
# Price
# Average      3.455042
# High         2.914286
# Low          3.731481
# Medium       3.156667
# very-high    3.123810
# Name: Rating, dtype: float64

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6  --- Ans
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
mrg.groupby(by="Style").Rating.median()
# Out:
# Style
# Brief       4.6
# Casual      4.6
# Flare       0.0
# Novelty     2.1
# OL          0.0
# Sexy        4.6
# bohemian    4.6
# cute        4.6
# fashion     4.0
# party       4.7
# sexy        4.5
# vintage     4.6
# work        4.7
# Name: Rating, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn --- Ans
# - Winter

# %%
# Summer sale vs Recommendation.
mrg[mrg.Recommendation == 1].Summer.mean()
# Out:
# 1469.8994974874372

# %%
# Spring sale vs Recommendation.
mrg[mrg.Recommendation == 1].Spring.mean()
# Out:
# 303.65829145728645

# %%
# Autumn sale vs Recommendation.
mrg[mrg.Recommendation == 1].Autumn.mean()
# Out:
# 2868.0603015075376

# %%
# Winter sale vs Recommendation.
mrg[mrg.Recommendation == 1].Winter.mean()
# Out:
# 1002.8090452261307

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium ------------------- Ans

# %%
# Size vs Recommendation.
mrg.groupby(by="Size").Recommendation.sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Size'>

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.
ht_data = pd.pivot_table(mrg,values="Recommendation",index="Style",columns="Price")
sns.heatmap(ht_data,cmap="RdYlGn",annot=True,center=0.427)
plt.show()

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
mrg.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine  SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck   sleeve less
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck         Petal
# 2  1190380701  vintage     High     0.0    L  Autumn   o-neck  full sleeves
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck  full sleeves
# 4   876339541     cute      Low     4.5    M  Summer   o-neck     butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Spring  \
# 0            NaN    chiffon     ruffles       animal               1  2660.0
# 1     microfiber        NaN     ruffles       animal               0   750.0
# 2       polyster        NaN         NaN        print               0     7.0
# 3           silk    chiffon  embroidary        print               1  1455.0
# 4  chiffonfabric    chiffon         bow          dot               0  1396.0
#
#     Summer  Winter   Autumn    total
# ...

# %%
# plot the heat map of Season, material and Recommendation.
ht_table2 = pd.pivot_table(data=mrg,values="Recommendation",index="Season",columns="Material")
sns.heatmap(ht_table2,cmap="RdYlGn",annot=True,)
plt.figure(figsize=[10,20])
plt.show()
